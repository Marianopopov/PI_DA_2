# %%
import pandas as pd

# %%
df = pd.read_csv('Datasets/clean/siniestos_limpio.csv')

# %%
df[df.isna()]
# Out:
#       Id Fecha  Año  Mes  Día Día semana Hora completa  Hora  Num víctimas  \
# 0    NaN   NaN  NaN  NaN  NaN        NaN           NaN   NaN           NaN
# 1    NaN   NaN  NaN  NaN  NaN        NaN           NaN   NaN           NaN
# 2    NaN   NaN  NaN  NaN  NaN        NaN           NaN   NaN           NaN
# 3    NaN   NaN  NaN  NaN  NaN        NaN           NaN   NaN           NaN
# 4    NaN   NaN  NaN  NaN  NaN        NaN           NaN   NaN           NaN
# ..   ...   ...  ...  ...  ...        ...           ...   ...           ...
# 712  NaN   NaN  NaN  NaN  NaN        NaN           NaN   NaN           NaN
# 713  NaN   NaN  NaN  NaN  NaN        NaN           NaN   NaN           NaN
# 714  NaN   NaN  NaN  NaN  NaN        NaN           NaN   NaN           NaN
# 715  NaN   NaN  NaN  NaN  NaN        NaN           NaN   NaN           NaN
# 716  NaN   NaN  NaN  NaN  NaN        NaN           NaN   NaN           NaN
#
# ...

# %%
df_filled = df.fillna("S/D")

# %%
df_filled.isna().sum()
# Out:
# Id                       0
# Fecha                    0
# Año                      0
# Mes                      0
# Día                      0
# Día semana               0
# Hora completa            0
# Hora                     0
# Num víctimas             0
# Participantes            0
# Rol                      0
# Acusado                  0
# Victima                  0
# Sexo                     0
# Edad                     0
# Rango etario             0
# Fecha fallecimiento      0
# Lugar del hecho          0
# Tipo de calle            0
# Calle                    0
# Cruce                    0
# Dirección normalizada    0
# Comuna                   0
# Xy (caba)                0
# Coordenada x             0
# Coordenada y             0
# Pos x                    0
# Pos y                    0
# Semestre con anio        0
# dtype: int64
